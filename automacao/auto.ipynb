# %%
import pyautogui

pyautogui.PAUSE = 1


"""pyautogui.press("win")
pyautogui.write("testeauto.xlsx")
pyautogui.press("backspace")
pyautogui.press("enter")"""


# clicar no campo turno
pyautogui.click(x=-1347, y=478)
# clicar no turno 2 
pyautogui.click(x=-1347, y=478)
# clicar no campo cns do prof
pyautogui.click(x=-732, y=510)
# #escrever no campo cns
pyautogui.write("francismar")
#selecionar o nome no cns
pyautogui.click(x=-750, y=533)
# clicar no campo cbo
pyautogui.click(x=-582, y=507)
#selecionar no campo cbo
pyautogui.click(x=-609, y=550)
# clicar no campo atividade
pyautogui.click(x=-1360, y=871)
# scroll
pyautogui.scroll(-900)

# clicar no campo publico alvo
pyautogui.click(x=-1358, y=299)
pyautogui.click(x=-1355, y=390)
pyautogui.click(x=-1360, y=458)
# clicar no campo temas para saúde
pyautogui.click(x=-1038, y=570)
# clicar em praticas
pyautogui.click(x=-695, y=370)


# 1
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("703603078354435")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("12/01/1946")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 2
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050044616688")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("24/12/1951")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 3
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("704101656779850")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("18/08/1940")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 4
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898001259015450")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("22/01/1969")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 5
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050046757246")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("10/02/1952")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 6
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050046254090077")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("24/12/1953")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# scrol para cima
pyautogui.scroll(500)

# Clicar no botão de numero de participantes
pyautogui.click(x=-1273, y=493)


# Clicar no botão de numero de participantes
pyautogui.write("06")

# %%
import pyautogui

pyautogui.PAUSE = 1


"""pyautogui.press("win")
pyautogui.write("testeauto.xlsx")
pyautogui.press("backspace")
pyautogui.press("enter")"""


# clicar no campo turno
pyautogui.click(x=-1347, y=478)
# clicar no turno 2 
pyautogui.click(x=-1347, y=478)
# clicar no campo cns do prof
pyautogui.click(x=-732, y=510)
# #escrever no campo cns
pyautogui.write("francismar")
#selecionar o nome no cns
pyautogui.click(x=-750, y=533)
# clicar no campo cbo
pyautogui.click(x=-582, y=507)
#selecionar no campo cbo
pyautogui.click(x=-609, y=550)
# clicar no campo atividade
pyautogui.click(x=-1360, y=871)
# scroll
pyautogui.scroll(-900)

# clicar no campo publico alvo
pyautogui.click(x=-1358, y=299)
pyautogui.click(x=-1355, y=390)
pyautogui.click(x=-1360, y=458)
# clicar no campo temas para saúde
pyautogui.click(x=-1038, y=570)
# clicar em praticas
pyautogui.click(x=-695, y=370)


# 1
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("703603078354435")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("12/01/1946")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 2
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050044616688")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("24/12/1951")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 3
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("704101656779850")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("18/08/1940")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 4
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898001259015450")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("22/01/1969")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 5
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050046757246")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("10/02/1952")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# 6
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("898050046254090077")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("24/12/1953")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)


# Clicar no botão de numero de participantes
pyautogui.click(x=-1273, y=493)


# 7
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("700508519401856")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("17/12/1936")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)


# Clicar no botão de numero de participantes
pyautogui.click(x=-1273, y=493)

# 8
# clicar no campo cpf
pyautogui.click(x=-1301, y=686)

# preencher o cpf
pyautogui.click(x=-1301, y=686)
pyautogui.write("708407295166064")

# clicar no campo datanasc
pyautogui.click(x=-1176, y=690)

# preencher a datanasc
pyautogui.click(x=-1176, y=690)
pyautogui.write("04/06/1955")

# clicar no campo sexo
pyautogui.click(x=-964, y=689)

# clicar no campo sexo/Fem
pyautogui.click(x=-1042, y=734)

# Clicar no botão confirmar
pyautogui.click(x=-473, y=725)

# scrol para cima
pyautogui.scroll(500)

# Clicar no botão de numero de participantes
pyautogui.click(x=-1273, y=493)


# Clicar no botão de numero de participantes
pyautogui.write("08")
